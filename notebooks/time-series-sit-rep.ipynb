# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
fname='../model/who_covid_19_situation_reports/who_covid_19_sit_rep_time_series/who_covid_19_sit_rep_time_series.csv'

# %%
df = pd.read_csv(fname)

# %%
df
# Out:
#                         Province/States    Country/Region  \
# 0                             Confirmed          Globally
# 1                             Confirmed    Mainland China
# 2                             Confirmed  Outside of China
# 3                             Suspected    Mainland China
# 4                                Severe    Mainland China
# ..                                  ...               ...
# 65                                  NaN             Egypt
# 66                                  NaN              Iran
# 67                                  NaN           Lebanon
# 68                                  NaN            Israel
# 69  Case on an international conveyance             Other
#
#                       WHO region  1/21/2020  1/22/2020  1/23/2020  1/24/2020  \
# 0                            NaN      282.0      314.0      581.0      846.0
# 1         Western Pacific Region      278.0      309.0      571.0      830.0
# ...

# %%
df['Country/Region']
# Out:
# 0             Globally
# 1       Mainland China
# 2     Outside of China
# 3       Mainland China
# 4       Mainland China
#             ...
# 65               Egypt
# 66                Iran
# 67             Lebanon
# 68              Israel
# 69               Other
# Name: Country/Region, Length: 70, dtype: object

# %%
usData = df[df['Country/Region'] == 'United States of America']

# %%
usData
# Out:
#    Province/States            Country/Region              WHO region  \
# 44             NaN  United States of America  Region of the Americas
#
#     1/21/2020  1/22/2020  1/23/2020  1/24/2020  1/25/2020  1/26/2020  \
# 44        NaN        NaN        1.0        1.0        2.0        2.0
#
#     1/27/2020  ...  2/15/2020  2/16/2020  2/17/2020  2/18/2020  2/19/2020  \
# 44        5.0  ...       15.0       15.0       15.0       15.0       15.0
#
#     2/20/2020  2/21/2020  2/22/2020  2/23/2020  2/24/2020
# 44       15.0       15.0       15.0       15.0       15.0
#
# [1 rows x 38 columns]

# %%
progress = usData.loc[:,'1/23/2020':]

# %%
progress
# Out:
#     1/23/2020  1/24/2020  1/25/2020  1/26/2020  1/27/2020  1/28/2020  \
# 44        1.0        1.0        2.0        2.0        5.0        5.0
#
#     1/29/2020  1/30/2020  1/31/2020  2/1/2020  ...  2/15/2020  2/16/2020  \
# 44        5.0        5.0        6.0       7.0  ...       15.0       15.0
#
#     2/17/2020  2/18/2020  2/19/2020  2/20/2020  2/21/2020  2/22/2020  \
# 44       15.0       15.0       15.0       15.0       15.0       15.0
#
#     2/23/2020  2/24/2020
# 44       15.0       15.0
#
# [1 rows x 33 columns]

# %%
y = progress.to_numpy()

# %%
xticks = list(progress.columns.values)

# %%
y = y.flatten()
plt.plot(y, 'o')

# %%
#fig = plt.gcf()
ax = plt.gca()
ax.set_xticklabels(xticks, rotation=45)
x = list(range(1, len(y)+1))
plt.plot(x, y, 'o')

         
#fig.autofmt_xdate(rotation=90)

# %%
sum(y)
# Out:
# 345.0
